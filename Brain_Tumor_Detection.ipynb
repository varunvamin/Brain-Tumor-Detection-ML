# %% [markdown]
# # Brain Tumor Detection
# Run the cells below to clone the repository, install dependencies, and run a prediction on an MRI image.

# %%
# !git clone https://github.com/varunvamin/Brain-Tumor-Detection-ML.git
# %cd Brain-Tumor-Detection-ML
# !pip install -r requirements.txt

# %% [markdown]
# ### Upload an MRI Image
# Run this cell to upload your own MRI image (e.g., `tumor.jpg`).

# %%
from google.colab import files

uploaded = files.upload()
image_name = list(uploaded.keys())[0]
print(f"Uploaded {image_name}")

# %% [markdown]
# ### Run Prediction

# %%
# !python brain_tumor_detection.py --mode predict --image "{image_name}"
